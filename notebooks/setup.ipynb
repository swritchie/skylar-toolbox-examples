# %% [markdown]
# # Set up

# %% [markdown]
# ## Change working directory

# %%
# %cd ../

# %% [markdown]
# ## Install packages

# %%
# !pip uninstall -q -y skylar_toolbox
# !pip install -q "skylar-toolbox @ git+https://github.com/swritchie/skylar-toolbox.git"
# !pip freeze > requirements.txt 
# !conda env export > environment.yaml
